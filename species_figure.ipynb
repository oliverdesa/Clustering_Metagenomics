# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# read csv
df = pd.read_csv('secreted_dles_per_tax.csv')

# select top 20
df = df.iloc[:20]

# %%
# Plot the top 20 species as a bar plot with seaborn
sns.set(style="whitegrid")
sns.set_color_codes("pastel")
sns.barplot(x="Lineage", y="Mean_DLE_freq", data=df,
            label="DLEs", color="b")

# Add a legend and informative axis label
plt.xlabel("Taxonomic Lineage")
plt.ylabel("Mean DLE Frequency")
plt.title("Mean DLE Frequency per Taxonomic Lineage")
plt.xticks(rotation=90)
plt.tight_layout()
plt.savefig('species_figure.png')
# Out:
# C:\Users\odesa\AppData\Local\Temp\ipykernel_4192\1230648039.py:12: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()

# %%
# Make a custom list to act as the X labels
x_labels = []
for lineage in df['Lineage']:
    x_labels.append(lineage.split(';')[-1])

x_labels = [x[3:] for x in x_labels]
print(x_labels)
# Out:
# ['Enterocloster citroniae', 'Bacillus subtilis', 'Planococcus massiliensis', 'Lactiplantibacillus pentosus', 'Clostridium beijerinckii', 'Emergencia sp900551775', 'Hungatella sp005845265', 'Lactiplantibacillus plantarum', 'Hungatella effluvii', 'Emergencia timonensis', 'GCA-900066135 sp900066135', 'CAG-41 sp900066215', 'TF01-11 sp000436755', 'Anaerostipes hadrus', 'Anaerostipes sp900066705', 'Micrococcus luteus', 'Bacillus licheniformis', 'Bacillus paralicheniformis', 'Bacillus sonorensis', 'Bacillus_A luti']

# %%
sns.set(style="whitegrid")
sns.set_color_codes("pastel")
ax = sns.barplot(x="Mean_DLE_freq", y="Lineage", data=df,
            label="DLEs", color="b")

# Add a legend and informative axis label
plt.xlabel("Mean DLE Frequency")
ax.set_ylabel("")
plt.title("Mean DLE Frequency per Species")
ax.set_yticklabels(x_labels)
plt.tight_layout()
plt.savefig('species_figure.png', dpi=300)
# Out:
# C:\Users\odesa\AppData\Local\Temp\ipykernel_4192\2153702828.py:10: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(x_labels)
